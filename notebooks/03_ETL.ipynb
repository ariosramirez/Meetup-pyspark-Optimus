# %% [markdown]
# * Aplicar transformaciones y dejar el Dataset para entrenar solamente

# %%
import findspark
import pandas as pd
import nltk
import re

from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.wrappers.scikit_learn import KerasClassifier

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import ngrams
from optimus import Optimus
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from unicodedata import normalize
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Start Spark

# %%
findspark.init()
spark = (
    SparkSession.builder
    .appName('meetUp_optimus')
    .getOrCreate()
)

# %% [markdown]
# #### Start Optimus

# %%
op = Optimus()
# Out:
# <style> /* Tables*/
#
#  .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table td {
#         border: 0px;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
#     .optimus_table tbody{
#         font-family: monospace;
#         border-bottom: 1px solid #cccccc;
#     }
#
#     /* Profiler */
#         .main{
#         width:100%;
#         overflow:auto;
#         border-bottom:1px solid #eeeeee;
#         padding: 10px 0;
#     }
#     .panel_profiler{
#         margin-right:2%;
#         float:left;
#         padding-bottom:2%;
#     }
#     .panel_profiler tbody{
#         font-family:monospace;
#     }
#     .title_profiler{
#         padding:20px;
#         background-color: #eeeeee
#     }
#     .info{
#         overflow: auto
#     }
#     .main td, main th{
#         padding:0em
#     }
#     .panel_profiler td {
#         padding:0.2em
#     }
#     .none, .true{
#         color:#0000ff
#     }
#     .optimus_table th {
#         font-family:sans-serif;
#     }
#
#     .info_items{
#         font-family:sans-serif;
#         font-size:10px;
#     }
# </style>

# %% [markdown]
# #### Read csv

# %%
df_items_meli = op.read.csv(
    '../data/train.csv',
    header=True
)

# %% [markdown]
# #### Download nltk stopwords, punkt, wordnet

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# #### Variables y constantes

# %%
stop_words = set(stopwords.words('spanish'))
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ####

# %% [markdown]
# filter dataframe

# %%
df_items_meli_tiny = df_items_meli.limit(200)

# %%
def normalizer(title, n_gram):
    #filter
    only_letters =  re.sub(
        r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", 
        r"\1",
        normalize( "NFD", title), 0, re.I
        ) 
    only_letters = re.sub(r'[^\w]', ' ', only_letters)
    #tokenize
    tokens = nltk.word_tokenize(only_letters)
    lower_case = [l.lower() for l in tokens]
    #stop_words
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    lemmas = [wordnet_lemmatizer.lemmatize(t) for t in filtered_result]
    
    #create n grams
    if n_gram > 1:
        grams = [''.join(word for word in tupla) for tupla in list(ngrams(lemmas, n_gram))]
    else:
        grams = []
    #union lemmas and grams
    lemmas_ngrams = lemmas + grams
    #list to str
    text = ' '.join(str(text) for text in lemmas_ngrams)
    return text

# %%
# float type output
normalizer_udf_str = udf(
    lambda x: normalizer(x, n_gram=2), StringType()
)

# %%
df_items_meli_tiny = (
    df_items_meli_tiny.select(
        '*',
        normalizer_udf_str('title').alias('title_clean_str'),
    )
)

# %%
df_items_meli_tiny.table(limit=10)
# Out:
# <div class="info_items">Viewing 10 of 200 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Flashes&#8901;Led&#8901;Pestañas&#8901;Luminoso&#8901;Falso&#8901;Pestañas&#8901;Para&#8901;Partido&#8901;'>Flashes&#8901;Led&#8901;Pestañas&#8901;Luminoso&#8901;Falso&#8901;Pestañas&#8901;Para&#8901;Partido&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='spanish'>spanish
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='FALSE_EYELASHES'>FALSE_EYELASHES
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='flash&#8901;led&#8901;pestan&#8901;a&#8901;luminoso&#8901;falso&#8901;pestan&#8901;a&#8901;partido&#8901;flashled&#8901;ledpestan&#8901;pestana&#8901;aluminoso&#8901;luminosofalso&#8901;falsopestan&#8901;pestana&#8901;apartido'>flash&#8901;led&#8901;pestan&#8901;a&#8901;luminoso&#8901;falso&#8901;pestan&#8901;a&#8901;partido&#8901;flashled&#8901;ledpe...
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='4&#8901;Microaspersor&#8901;Irrigação&#8901;Ultra&#8901;7,20&#8901;Metros'>4&#8901;Microaspersor&#8901;Irrigação&#8901;Ultra&#8901;7,20&#8901;Metros
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='IRRIGATION_SPRINKLERS'>IRRIGATION_SPRINKLERS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4&#8901;microasperso

# %%
df_pandas = df_items_meli_tiny.select('title_clean_str', 'category').toPandas()
title_values = df_pandas.loc[:, 'title_clean_str']
y_category = df_pandas.loc[:, 'category']

# %%
from pyspark.ml.feature import HashingTF, IDF, Tokenizer

# %%
tokenizer = Tokenizer(inputCol="title_clean_str", outputCol="words")
wordsData = tokenizer.transform(df_items_meli_tiny)

# %%
hashingTF = HashingTF(inputCol="words", outputCol="rawFeatures", numFeatures=50000)
featurizedData = hashingTF.transform(wordsData)

# %%
from pyspark.sql.functions import col

# %%
idf = IDF(inputCol="rawFeatures", outputCol="rawFeatures_IDF")
idfModel = idf.fit(featurizedData)
rescaledData = idfModel.transform(featurizedData)

# %% [markdown]
# Label to numeric column

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol="category", outputCol="label")
rescaledData = indexer.fit(rescaledData).transform(rescaledData)

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=["rawFeatures_IDF"],
    outputCol="features")

transformed = assembler.transform(rescaledData)

# %%
transformed.table(10)
# Out:
# <div class="info_items">Viewing 10 of 200 rows / 10 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">title</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">label_quality</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">language</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">category</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">title_clean_str</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">words</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rawFeatures</div>
#             <div class="data_type">7 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rawFeatures_IDF</div>
#             <div class="data_type">8 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">label</div>
#             <div class="data_type">9 (double)</div>
#             <div class="data_type">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">features</div>
#             <div class="data_type">10 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Hidrolavadora&#8901;Lavor&#8901;One&#8901;120&#8901;Bar&#8901;1700w&#8901;&#8901;Bomba&#8901;Aluminio&#8901;Italia'>Hidrolavadora&#8901;Lavor&#8901;One&#8901;120&#8901;Bar&#8901;1700w&#8901;&#8901;Bomba&#8901;Aluminio&#8901;Italia
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='spanish'>spanish
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='ELECTRIC_PRESSURE_WASHERS'>ELECTRIC_PRESSURE_WASHERS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='hidrolavadora&#8901;lavor&#8901;one&#8901;120&#8901;bar&#8901;1700w&#8901;bomba&#8901;aluminio&#8901;italia&#8901;hidrolavadoralavor&#8901;lavorone&#8901;one120&#8901;120bar&#8901;bar1700w&#8901;1700wbomba&#8901;bombaaluminio&#8901;aluminioitalia'>hidrolavadora&#8901;lavor&#8901;one&#8901;120&#8901;bar&#8901;1700w&#8901;bomba&#8901;aluminio&#8901;italia&#8901;hidrolavado...
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['hidrolavadora',&#8901;'lavor',&#8901;'one',&#8901;'120',&#8901;'bar',&#8901;'1700w',&#8901;'bomba',&#8901;'aluminio',&#8901;'italia',&#8901;'hidrolavadoralavor',&#8901;'lavorone',&#8901;'one120',&#8901;'120bar',&#8901;'bar1700w',&#8901;'1700wbomba',&#8901;'bombaaluminio',&#8901;'aluminioitalia']'>['hidrolavadora',&#8901;'lavor',&#8901;'one',&#8901;'120',&#8901;'bar',&#8901;'1700w',&#8901;'bomba',&#8901;'aluminio',&#8901...
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='130.0'>130.0
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Placa&#8901;De&#8901;Sonido&#8901;-&#8901;Behringer&#8901;Umc22'>Placa&#8901;De&#8901;Sonido&#8901;-&#8901;Behringer&#8901;Umc22
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='spanish'>spanish
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='SOUND_CARDS'>SOUND_CARDS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='placa&#8901;sonido&#8901;behringer&#8901;umc22&#8901;placasonido&#8901;sonidobehringer&#8901;behringerumc22'>placa&#8901;sonido&#8901;behringer&#8901;umc22&#8901;placasonido&#8901;sonidobehringer&#8901;behringerumc22
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['placa',&#8901;'sonido',&#8901;'behringer',&#8901;'umc22',&#8901;'placasonido',&#8901;'sonidobehringer',&#8901;'behringerumc22']'>['placa',&#8901;'sonido',&#8901;'behringer',&#8901;'umc22',&#8901;'placasonido',&#8901;'sonidobehringer',&#8901;'behringerumc22']
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='87.0'>87.0
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Maquina&#8901;De&#8901;Lavar&#8901;Electrolux&#8901;12&#8901;Kilos'>Maquina&#8901;De&#8901;Lavar&#8901;Electrolux&#8901;12&#8901;Kilos
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='WASHING_MACHINES'>WASHING_MACHINES
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='maquina&#8901;lavar&#8901;electrolux&#8901;12&#8901;kilo&#8901;maquinalavar&#8901;lavarelectrolux&#8901;electrolux12&#8901;12kilo'>maquina&#8901;lavar&#8901;electrolux&#8901;12&#8901;kilo&#8901;maquinalavar&#8901;lavarelectrolux&#8901;electrolux12&#8901;12kilo
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['maquina',&#8901;'l

# %% [raw]
# from pyspark.mllib.regression import LabeledPoint
# from pyspark.sql.functions import col
#
# transformed = (
#     transformed.select(
#         col("label"), col("features")
#     )
#     .rdd
#     .map(lambda row: LabeledPoint(row.label, row.features))
# )

# %%
from pyspark.ml.classification import LogisticRegression

lr_classifier = LogisticRegression(family="multinomial")
lr_classifier.fit(transformed)
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 35544)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)

# %%
from pyspark.ml.classification import GBTClassifier

model = GBTClassifier(labelCol="label", featuresCol="features", maxIter=10)
model.fit(transformed)
