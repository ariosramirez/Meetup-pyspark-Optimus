# %% [markdown]
# # Datos

# %% [markdown]
# #### Descargar "train dataset"
# ***

# %%
! wget --directory-prefix=../data https://meli-data-challenge.s3.amazonaws.com/train.csv.gz
# Out:
# --2020-01-17 17:21:53--  https://meli-data-challenge.s3.amazonaws.com/train.csv.gz
# Resolving meli-data-challenge.s3.amazonaws.com (meli-data-challenge.s3.amazonaws.com)... 52.216.94.99
# Connecting to meli-data-challenge.s3.amazonaws.com (meli-data-challenge.s3.amazonaws.com)|52.216.94.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 691651384 (660M) [application/x-gzip]
# Saving to: ‘../data/train.csv.gz.1’
#
# train.csv.gz.1      100%[===================>] 659.61M  96.7MB/s    in 6.8s
#
# 2020-01-17 17:22:00 (96.5 MB/s) - ‘../data/train.csv.gz.1’ saved [691651384/691651384]

# %% [markdown]
# #### descomprimir el dataset
# ***

# %%
# !gunzip -f ../data/train.csv.gz  ../data/train.csv
# Out:
# gzip: ../data/train.csv: unknown suffix -- ignored

# %% [markdown]
# ## Genial, ya tienes los datos

# %% [markdown]
# ![SegmentLocal](https://media.giphy.com/media/fQim4EyJXIUaBn9uRe/giphy.gif "segment")

# %% [markdown]
# ## imports

# %%
import findspark
import pandas as pd
import nltk
import re

from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.wrappers.scikit_learn import KerasClassifier

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import ngrams
from optimus import Optimus
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from unicodedata import normalize
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Start Spark

# %%
findspark.init()
spark = (
    SparkSession.builder
    .config("spark.executor.memory", "30g")
    .config("spark.driver.maxResultSize", "30g")
    .config("spark.driver.memory", "30g")
    .appName('meetUp_optimus')
    .getOrCreate()
    
)

# %% [markdown]
# #### Start Optimus

# %%
op = Optimus()
# Out:
# <style> /* Tables*/
#
#  .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table td {
#         border: 0px;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
#     .optimus_table tbody{
#         font-family: monospace;
#         border-bottom: 1px solid #cccccc;
#     }
#
#     /* Profiler */
#         .main{
#         width:100%;
#         overflow:auto;
#         border-bottom:1px solid #eeeeee;
#         padding: 10px 0;
#     }
#     .panel_profiler{
#         margin-right:2%;
#         float:left;
#         padding-bottom:2%;
#     }
#     .panel_profiler tbody{
#         font-family:monospace;
#     }
#     .title_profiler{
#         padding:20px;
#         background-color: #eeeeee
#     }
#     .info{
#         overflow: auto
#     }
#     .main td, main th{
#         padding:0em
#     }
#     .panel_profiler td {
#         padding:0.2em
#     }
#     .none, .true{
#         color:#0000ff
#     }
#     .optimus_table th {
#         font-family:sans-serif;
#     }
#
#     .info_items{
#         font-family:sans-serif;
#         font-size:10px;
#     }
# </style>

# %% [markdown]
# #### Read csv

# %%
df_train = op.read.csv(
    '../data/train.csv',
    header=True
)

# %% [markdown]
# Objeto Dataframe de Spark

# %%
df_train?
# Out:
# Type:        DataFrame
# String form: DataFrame[title: string, label_quality: string, language: string, category: string]
# File:        /opt/conda/lib/python3.7/site-packages/pyspark/sql/dataframe.py
# Docstring:
# A distributed collection of data grouped into named columns.
#
# A :class:`DataFrame` is equivalent to a relational table in Spark SQL,
# and can be created using various functions in :class:`SparkSession`::
#
#     people = spark.read.parquet("...")
#
# Once created, it can be manipulated using the various domain-specific-language
# (DSL) functions defined in: :class:`DataFrame`, :class:`Column`.
#
# To select a column from the data frame, use the apply method::
#
#     ageCol = people.age
#
# A more concrete example::
#
#     # To create DataFrame using SparkSession
#     people = spark.read.parquet("...")
#     department = spark.read.parquet("...")
#
#     people.filter(people.age > 30).join(department, people.deptId == department.id) \
#       .groupBy(department.name, "gender").agg({"salary": "avg", "age": "max"})
#
# .. versionadded:: 1.3

# %% [markdown]
# ### visualize data with Spark

# %%
df_train.show(20)
# Out:
# +--------------------+-------------+----------+--------------------+
# |               title|label_quality|  language|            category|
# +--------------------+-------------+----------+--------------------+
# |Hidrolavadora Lav...|   unreliable|   spanish|ELECTRIC_PRESSURE...|
# |Placa De Sonido -...|   unreliable|   spanish|         SOUND_CARDS|
# |Maquina De Lavar ...|   unreliable|portuguese|    WASHING_MACHINES|
# |Par Disco De Frei...|   unreliable|portuguese| VEHICLE_BRAKE_DISCS|
# |Flashes Led Pesta...|   unreliable|   spanish|     FALSE_EYELASHES|
# |4 Microaspersor I...|   unreliable|portuguese|IRRIGATION_SPRINK...|
# |Raquete Clash 100...|   unreliable|portuguese|            RACQUETS|
# |Kit Tripe Para Ce...|   unreliable|portuguese|      CAMERA_TRIPODS|
# |Filtro Ar Bonanza...|   unreliable|portuguese|AUTOMOTIVE_AIR_FI...|
# |Gatito Lunchera N...|   unreliable|   spanish|          LUNCHBOXES|
# |Condensador Bosch...|   unreliable|portuguese|   CAR_AC_CONDENSERS|
# |Rosario Contador ...|   unreliable|   spanish|       BILL_COUNTERS|
# |     Banhos Mágicos |   unreliable|portuguese|      ESSENTIAL_OILS|
# |Caixa Setor Hidra...|   unreliable|portuguese|CAR_POWER_STEERIN...|
# |Tupia Coluna Lami...|   unreliable|portuguese|      PLUNGE_ROUTERS|
# |Touca Porco Com C...|   unreliable|portuguese|   HAIRDRESSING_CAPS|
# |Projeto Unidade H...|     reliable|portuguese|     AIR_COMPRESSORS|
# |Maleta Para Guard...|   unreliable|portuguese|  MAKEUP_TRAIN_CASES|
# |Battery Pack Huaw...|   unreliable|   spanish|PORTABLE_CELLPHON...|
# |Capa De Cilindro ...|   unreliable|portuguese|PARTY_DECORATIVE_...|
# +--------------------+-------------+----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### visualize data with Optimus

# %%
df_train.table(20)
# Out:
# <div class="info_items">Viewing 20 of 20.0 million rows / 4 columns</div>
# <div class="info_items">13 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">title</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">label_quality</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">language</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">category</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Hidrolavadora&#8901;Lavor&#8901;One&#8901;120&#8901;Bar&#8901;1700w&#8901;&#8901;Bomba&#8901;Aluminio&#8901;Italia'>Hidrolavadora&#8901;Lavor&#8901;One&#8901;120&#8901;Bar&#8901;1700w&#8901;&#8901;Bomba&#8901;Aluminio&#8901;Italia
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='spanish'>spanish
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='ELECTRIC_PRESSURE_WASHERS'>ELECTRIC_PRESSURE_WASHERS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Placa&#8901;De&#8901;Sonido&#8901;-&#8901;Behringer&#8901;Umc22'>Placa&#8901;De&#8901;Sonido&#8901;-&#8901;Behringer&#8901;Umc22
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='spanish'>spanish
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='SOUND_CARDS'>SOUND_CARDS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Maquina&#8901;De&#8901;Lavar&#8901;Electrolux&#8901;12&#8901;Kilos'>Maquina&#8901;De&#8901;Lavar&#8901;Electrolux&#8901;12&#8901;Kilos
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='WASHING_MACHINES'>WASHING_MACHINES
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Par&#8901;Disco&#8901;De&#8901;Freio&#8901;Diant&#8901;Vent&#8901;Gol&#8901;8v&#8901;08/&#8901;Fremax&#8901;Bd5298'>Par&#8901;Disco&#8901;De&#8901;Freio&#8901;Diant&#8901;Vent&#8901;Gol&#8901;8v&#8901;08/&#8901;Fremax&#8901;Bd5298
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='VEHICLE_BRAKE_DISCS'>VEHICLE_BRAKE_DISCS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Flashes&#8901;Led&#8901;Pestañas&#8901;Luminoso&#8901;Falso&#8901;Pestañas&#8901;Para&#8901;Partido&#8901;'>Flashes&#8901;Led&#8901;Pestañas&#8901;Luminoso&#8901;Falso&#8901;Pestañas&#8901;Para&#8901;Partido&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='spanish'>spanish
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='FALSE_EYELASHES'>FALSE_EYELASHES
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='4&#8901;Microaspersor&#8901;Irrigação&#8901;Ultra&#8901;7,20&#8901;Metros'>4&#8901;Microaspersor&#8901;Irrigação&#8901;Ultra&#8901;7,20&#8901;Metros
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='IRRIGATION_SPRINKLERS'>IRRIGATION_SPRINKLERS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Raquete&#8901;Clash&#8901;100&#8901;Tour&#8901;-&#8901;Nova'>Raquete&#8901;Clash&#8901;100&#8901;Tour&#8901;-&#8901;Nova
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='RACQUETS'>RACQUETS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Kit&#8901;Tripe&#8901;Para&#8901;Celular&#8901;Ou&#8901;Câmera&#8901;Fotog&#8901;1,20m&#8901;+&#8901;Brinde&#8901;+&#8901;Nf-e'>Kit&#8901;Tripe&#8901;Para&#8901;Celular&#8901;Ou&#8901;Câmera&#8901;Fotog&#8901;1,20m&#8901;+&#8901;Brinde&#8901;+&#8901;Nf-e
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='CAMERA_TRIPODS'>CAMERA_TRIPODS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Filtro&#8901;Ar&#8901;Bonanza&#8901;1984/1990&#8901;Sar3589'>Filtro&#8901;Ar&#8901;Bonanza&#8901;1984/1990&#8901;Sar3589
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='portuguese'>portuguese
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AUTOMOTIVE_AIR_FILTERS'>AUTOMOTIVE_AIR_FILTERS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Gatito&#8901;Lunchera&#8901;Neoprene&#8901;'>Gatito&#8901;Lunchera&#8901;Neoprene&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='unreliable'>unreliable
#             </div>
#         </t

# %% [markdown]
# ### Graficar Dataframe con Spark

# %% [markdown]
# Generar los cálculos con Spark y luego pasar a pandas
#
# *Spark nativo no tiene implementado gráficos*

# %%
df_items_language_gb_pd = df_train.groupby('language').count().toPandas()

# %%
df_items_language_gb_pd.plot.bar(x='language',y='count')

# %% [markdown]
# ### Graficar Dataframe con Optimus

# %%
df_train.plot.frequency('language')

# %% [markdown]
# #### Vista general del dataframe

# %%
op.profiler.run(df_train, columns=df_train.columns, infer=False)
# Out:
# Including 'nan' as Null in processing 'title'
# Including 'nan' as Null in processing 'label_quality'
# Including 'nan' as Null in processing 'language'
# Including 'nan' as Null in processing 'category'
# Including 'nan' as Null in processing 'title'
# Including 'nan' as Null in processing 'label_quality'
# Including 'nan' as Null in processing 'language'
# Including 'nan' as Null in processing 'category'
# <div class="title_profiler">
#     <h1>Overview</h1>
# </div>
# <div class="main">
#     <div class="panel_profiler">
#         <h2>Dataset info</h2>
#         <table>
#             <tbody>
#             <tr>
#                 <td>Number of columns</td>
#                 <td>4</td>
#
#             </tr>
#             <tr>
#                 <td>Number of rows</td>
#                 <td>20000000</td>
#
#             </tr>
#             <tr>
#                 <td>Total Missing (%)</td>
#                 <td>0.0%</td>
#
#             </tr>
#             <tr>
#                 <td>Total size in memory</td>
#                 <td>-1 Bytes</td>
#
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="panel_profiler">
#         <h2>Column types</h2>
#         <table>
#             <tbody>
#             <tr>
#                 <td>String</td>
#                 <td>4</td>
#
#             </tr>
#             <tr>
#                 <td>Numeric</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Date</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Bool</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Array</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Not available</td>
#                 <td>0</td>
#
#             </tr>
#             </tbody>
#         </table>
#     </div>
# </div><link rel="stylesheet" type="text/css" href="optimus/styles/styles.css">
#
#
# <div class="main">
#     <div class="info">
#
#
#
#         <div class="panel_profiler">
#             <div>
#                 <h2>title</h2>
#                 <span>categorical</span>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>Unique</td>
#                     <td> 20105291</td>
#                 </tr>
#                 <tr>
#                     <td>Unique (%)</td>
#                     <td> 100.526</td>
#                 </tr>
#                 <tr>
#                     <td>Missing</td>
#                     <td>0.0</td>
#                 </tr>
#                 <tr>
#                     <td>Missing (%)</td>
#                     <td>0</td>
#                 </tr>
#                 </tbody>
#             </table>
#             <div>
#                 <h3>
#                     Datatypes
#                 </h3>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>
#                         String
#                     </td>
#                     <td>
#                         19999999
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Integer
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Float
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Bool
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Date
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Missing
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Null
#                     </td>
#                     <td>
#                         1
#                     </td>
#
#                 </tr>
#                 </tbody>
#             </table>
#
#
#         </div>
#         <div class="panel_profiler">
#             <h3>Frequency</h3>
#             <table>
#
#                 <tr>
#                     <th>Value</th>
#                     <th>Count</th>
#                     <th>Frecuency (%)</th>
#                 </tr>
#
#                 <tr>
#                     <td>Álbum Para Fotos</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>Água Micelar Purificante Chronos - 150ml</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch Apple 8gb</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 8gb White</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 8gb A1367</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 8gb</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 8 Gb</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 64gb </td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 64gb</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>iPod Touch 64g</td>
#                     <td>2</td>
#                     <td>0.0%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>"Missing"</td>
#                     <td>0</td>
#                     <td>0.0%</td>
#                 </tr>
#
#             </table>
#         </div>
#
#
#
#     </div>
#     <table>
#
#         <tr>
#
#             <td>
#
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#             </td>
#         </tr>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#
#
#
#
#
#     </table>
# </div><link rel="stylesheet" type="text/css" href="optimus/styles/styles.css">
#
#
# <div class="main">
#     <div class="info">
#
#
#
#         <div class="panel_profiler">
#             <div>
#                 <h2>label_quality</h2>
#                 <span>categorical</span>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>Unique</td>
#                     <td> 2</td>
#                 </tr>
#                 <tr>
#                     <td>Unique (%)</td>
#                     <td> 0.0</td>
#                 </tr>
#                 <tr>
#                     <td>Missing</td>
#                     <td>0.0</td>
#                 </tr>
#                 <tr>
#                     <td>Missing (%)</td>
#                     <td>0</td>
#                 </tr>
#                 </tbody>
#             </table>
#             <div>
#                 <h3>
#                     Datatypes
#                 </h3>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>
#                         String
#                     </td>
#                     <td>
#                         19999975
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Integer
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>

# %% [markdown]
# # EDA

# %% [markdown]
# EDA descripción.
#  * Descrición de dataset
#      - Cuantas columnas tiene
#      - el tipo de las columnas
#      - cuantos null tiene cada columna
#  * Descripción de la columna objetivo
#      - Cantidad de etiquetas
#      - distribución de los etiquetados

# %% [markdown]
# #### Dataset

# %% [markdown]
# ¿Cuantas columnas tiene este dataset?

# %%
columns_df = df_train.columns
print(f'Este Dataset tiene {len(columns_df)} columnas')
print(f'Son: {columns_df}')
# Out:
# Este Dataset tiene 4 columnas
# Son: ['title', 'label_quality', 'language', 'category']

# %% [markdown]
# ##### Tipos de las columnas

# %%
df_train.printSchema()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- label_quality: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- category: string (nullable = true)

# %%
nulls_in_col = df_train.cols.count_na(columns_df)
# Out:
# Including 'nan' as Null in processing 'title'
# Including 'nan' as Null in processing 'label_quality'
# Including 'nan' as Null in processing 'language'
# Including 'nan' as Null in processing 'category'

# %%
pd.Series(
    nulls_in_col,
    name='Nulls'
)
# Out:
# title             1
# label_quality    25
# language         25
# category         25
# Name: Nulls, dtype: int64

# %% [markdown]
# Los nulls se tienen que eliminar

# %% [markdown]
# #### Columna target

# %%
df_train.select('category').limit(100).distinct().table(10)
# Out:
# <div class="info_items">Viewing 10 of 97 rows / 1 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">category</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='ELECTRIC_PRESSURE_WASHERS'>ELECTRIC_PRESSURE_WASHERS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='SOUND_CARDS'>SOUND_CARDS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='WASHING_MACHINES'>WASHING_MACHINES
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='VEHICLE_BRAKE_DISCS'>VEHICLE_BRAKE_DISCS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='FALSE_EYELASHES'>FALSE_EYELASHES
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='IRRIGATION_SPRINKLERS'>IRRIGATION_SPRINKLERS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='RACQUETS'>RACQUETS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='CAMERA_TRIPODS'>CAMERA_TRIPODS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='AUTOMOTIVE_AIR_FILTERS'>AUTOMOTIVE_AIR_FILTERS
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='LUNCHBOXES'>LUNCHBOXES
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 10 of 97 rows / 1 columns</div>
# <div class="info_items">1 partition(s)</div>

# %%
df_train.groupby('category').count().sort('count', ascending=False).table(10)
# Out:
# <div class="info_items">Viewing 10 of 1589 rows / 2 columns</div>
# <div class="info_items">200 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">category</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">count</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='PANTS'>PANTS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='35973'>35973
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='COFFEE_MAKERS'>COFFEE_MAKERS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='35104'>35104
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='BABY_CAR_SEATS'>BABY_CAR_SEATS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='34163'>34163
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='MUSICAL_KEYBOARDS'>MUSICAL_KEYBOARDS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='33222'>33222
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='MATTRESSES'>MATTRESSES
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='32967'>32967
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='PUREBRED_DOGS'>PUREBRED_DOGS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='32928'>32928
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='RANGES'>RANGES
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='32645'>32645
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='REFRIGERATORS'>REFRIGERATORS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='32635'>32635
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='MOTORCYCLE_JACKETS'>MOTORCYCLE_JACKETS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='32615'>32615
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='HAIR_CLIPPERS'>HAIR_CLIPPERS
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='32372'>32372
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 10 of 1589 rows / 2 columns</div>
# <div class="info_items">200 partition(s)</div>

# %%
groupby_category_items = df_train.groupby('category').count().sort('count', ascending=False).cache()

# %%
groupby_category_items.show()
# Out:
# +------------------+-----+
# |          category|count|
# +------------------+-----+
# |             PANTS|35973|
# |     COFFEE_MAKERS|35104|
# |    BABY_CAR_SEATS|34163|
# | MUSICAL_KEYBOARDS|33222|
# |        MATTRESSES|32967|
# |     PUREBRED_DOGS|32928|
# |            RANGES|32645|
# |     REFRIGERATORS|32635|
# |MOTORCYCLE_JACKETS|32615|
# |     HAIR_CLIPPERS|32372|
# |            SHORTS|31685|
# |         SUITCASES|31580|
# |      MEMORY_CARDS|31564|
# |             WINES|31399|
# |     ROLLER_SKATES|31371|
# |    BABY_STROLLERS|31353|
# |   SEWING_MACHINES|31129|
# |   ELECTRIC_DRILLS|30820|
# |     KITCHEN_SINKS|30635|
# |       WALL_CLOCKS|30600|
# +------------------+-----+
# only showing top 20 rows

# %%
df_train.plot.frequency('category', buckets=20)

# %% [markdown]
# ###  Create a Dataframe

# %%
from pyspark.sql.types import *
from datetime import date, datetime

df = op.create.df(
    [
        ("names", "str", True), 
        ("height(ft)","int", True), 
        ("function", "str", True), 
        ("rank", "int", True), 
        ("age","int",True),
        ("weight(t)","float",True),
        ("japanese name", ArrayType(StringType()), True),
        ("last position seen", "str", True),
        ("date arrival", "str", True),
        ("last date seen", "str", True),
        ("attributes", ArrayType(FloatType()), True),
        ("DateType"),
        ("Tiemstamp"),
        ("Cybertronian", "bool", True), 
        ("NullType", "null", True),
    ],
    [
        ("Optim'us", 28, "Leader", 10, 5000000, 4.3, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
         "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True,
         None),
        ("bumbl#ebéé  ", 17, "Espionage", 7, 5000000, 2.0, ["Bumble", "Goldback"], "10.642707,-71.612534", "1980/04/10",
         "2015/08/10", [5.334, 2000.0], date(2015, 8, 10), datetime(2014, 6, 24), True,
         None),
        ("ironhide&", 26, "Security", 7, 5000000, 4.0, ["Roadbuster"], "37.789563,-122.400356", "1980/04/10",
         "2014/07/10", [7.9248, 4000.0], date(2014, 6, 24), datetime(2014, 6, 24), True,
         None),
        ("Jazz", 13, "First Lieutenant", 8, 5000000, 1.80, ["Meister"], "33.670666,-117.841553", "1980/04/10",
         "2013/06/10", [3.9624, 1800.0], date(2013, 6, 24), datetime(2014, 6, 24), True, None),
        ("Megatron", None, "None", 10, 5000000, 5.70, ["Megatron"], None, "1980/04/10", "2012/05/10", [None, 5700.0],
         date(2012, 5, 10), datetime(2014, 6, 24), True, None),
        ("Metroplex_)^$", 300, "Battle Station", 8, 5000000, None, ["Metroflex"], None, "1980/04/10", "2011/04/10",
         [91.44, None], date(2011, 4, 10), datetime(2014, 6, 24), True, None),

    ], infer_schema = True).h_repartition(1)

# %%
df.table()
# Out:
# <div class="info_items">Viewing 6 of 6 rows / 15 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">DateType</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">15 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim'us'>Optim'us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='28'>28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Inochi',&#8901;'Convoy']'>['Inochi',&#8901;'Convoy']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,&#8901;4300.0]'>[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé&#8901;&#8901;'>bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Bumble',&#8901;'Goldback']'>['Bumble',&#8901;'Goldback']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,&#8901;2000.0]'>[5.334000110626221,&#8901;2000.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015-08-10'>2015-08-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True

# %%
# This is a custom function
def func(value, arg):
    return "this was a number"
    
new_df = df\
    .rows.sort("rank","desc")\
    .withColumn('new_age', df.age)\
    .cols.lower(["names","function"])\
    .cols.date_transform("date arrival", "yyyy/MM/dd", "dd-MM-YYYY")\
    .cols.years_between("date arrival", "dd-MM-YYYY", output_cols = "from arrival")\
    .cols.remove_accents("names")\
    .cols.remove_special_chars("names")\
    .rows.drop(df["rank"]>8)\
    .cols.rename(str.lower)\
    .cols.trim("*")\
    .cols.unnest("japanese name", output_cols="other names")\
    .cols.unnest("last position seen",separator=",", output_cols="pos")\
    .cols.drop(["last position seen", "japanese name","date arrival", "cybertronian", "nulltype"])

# %%
new_df.table()
# Out:
# <div class="info_items">Viewing 4 of 4 rows / 16 columns</div>
# <div class="info_items">3 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">8 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">datetype</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">tiemstamp</div>
#             <div class="data_type">10 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new_age</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">from arrival</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">other names_0</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">other names_1</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">pos_0</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">pos_1</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='jazz'>jazz
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='13'>13
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='first&#8901;lieutenant'>first&#8901;lieutenant
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='8'>8
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1.8'>1.8
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2013/06/10'>2013/06/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[3.962399959564209,&#8901;1800.0]'>[3.962399959564209,&#8901;1800.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2013-06-24'>2013-06-24
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='40.0484'>40.0484
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Meister'>Meister
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='33.670666'>33.670666
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-117.841553'>-117.841553
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='metroplex'>metroplex
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='300'>300
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='battle&#8901;station'>battle&#8901;station
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='8'>8
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2011/04/10'>2011/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[91.44000244140625,&#8901;None]'>[91.44000244140625,&#8901;None]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2011-04-10'>2011-04-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='40.0484'>40.0484
#             </div>
#         </td

# %%
def func(value, args):
    return value + args[0] + args[1]

df.cols.apply("height(ft)",func,"int", [1,2]).table()
# Out:
# <div class="info_items">Viewing 6 of 6 rows / 15 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">DateType</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">15 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim'us'>Optim'us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='31'>31
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Inochi',&#8901;'Convoy']'>['Inochi',&#8901;'Convoy']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,&#8901;4300.0]'>[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé&#8901;&#8901;'>bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='20'>20
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Bumble',&#8901;'Goldback']'>['Bumble',&#8901;'Goldback']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,&#8901;2000.0]'>[5.334000110626221,&#8901;2000.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015-08-10'>2015-08-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True

# %%
op.output("html")
op.output("ascii")

# %% [markdown]
# ## Data profiling

# %% [markdown]
# ##### read Meteorite Landings CSV

# %%
df = op.load.csv("https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/Meteorite_Landings.csv").h_repartition()

# %%
op.profiler.run(df, "mass (g)", infer=False)
# Out:
# Including 'nan' as Null in processing 'name'
# Including 'nan' as Null in processing 'nametype'
# Including 'nan' as Null in processing 'recclass'
# Including 'nan' as Null in processing 'fall'
# Including 'nan' as Null in processing 'year'
# Including 'nan' as Null in processing 'GeoLocation'
# <div class="title_profiler">
#     <h1>Overview</h1>
# </div>
# <div class="main">
#     <div class="panel_profiler">
#         <h2>Dataset info</h2>
#         <table>
#             <tbody>
#             <tr>
#                 <td>Number of columns</td>
#                 <td>10</td>
#
#             </tr>
#             <tr>
#                 <td>Number of rows</td>
#                 <td>45716</td>
#
#             </tr>
#             <tr>
#                 <td>Total Missing (%)</td>
#                 <td>0.49%</td>
#
#             </tr>
#             <tr>
#                 <td>Total size in memory</td>
#                 <td>-1 Bytes</td>
#
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="panel_profiler">
#         <h2>Column types</h2>
#         <table>
#             <tbody>
#             <tr>
#                 <td>String</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Numeric</td>
#                 <td>1</td>
#
#             </tr>
#             <tr>
#                 <td>Date</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Bool</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Array</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Not available</td>
#                 <td>0</td>
#
#             </tr>
#             </tbody>
#         </table>
#     </div>
# </div><link rel="stylesheet" type="text/css" href="optimus/styles/styles.css">
#
#
# <div class="main">
#     <div class="info">
#
#
#
#         <div class="panel_profiler">
#             <div>
#                 <h2>mass (g)</h2>
#                 <span>numeric</span>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>Unique</td>
#                     <td> 12497</td>
#                 </tr>
#                 <tr>
#                     <td>Unique (%)</td>
#                     <td> 27.336</td>
#                 </tr>
#                 <tr>
#                     <td>Missing</td>
#                     <td>0.0</td>
#                 </tr>
#                 <tr>
#                     <td>Missing (%)</td>
#                     <td>0</td>
#                 </tr>
#                 </tbody>
#             </table>
#             <div>
#                 <h3>
#                     Datatypes
#                 </h3>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>
#                         String
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Integer
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Float
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Bool
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Date
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Missing
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Null
#                     </td>
#                     <td>
#                         131
#                     </td>
#
#                 </tr>
#                 </tbody>
#             </table>
#
#             <div>
#                 <h3>
#                     Basic Stats
#                 </h3>
#
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>Mean</td>
#                     <td>13278.07855</td>
#                 </tr>
#                 <tr>
#                     <td>Minimum</td>
#                     <td>0.0</td>
#                 </tr>
#                 <tr>
#                     <td>Maximum</td>
#                     <td>60000000.0</td>
#                 </tr>
#                 <tr>
#                     <td>Zeros(%)</td>
#                     <td></td>
#                 </tr>
#
#                 </tbody>
#             </table>
#
#
#         </div>
#         <div class="panel_profiler">
#             <h3>Frequency</h3>
#             <table>
#
#                 <tr>
#                     <th>Value</th>
#                     <th>Count</th>
#                     <th>Frecuency (%)</th>
#                 </tr>
#
#                 <tr>
#                     <td>1.3</td>
#                     <td>171</td>
#                     <td>0.374%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>1.2</td>
#                     <td>140</td>
#                     <td>0.306%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>1.4</td>
#                     <td>138</td>
#                     <td>0.302%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>None</td>
#                     <td>131</td>
#                     <td>0.287%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>2.1</td>
#                     <td>130</td>
#                     <td>0.284%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>2.4</td>
#                     <td>126</td>
#                     <td>0.276%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>1.6</td>
#                     <td>120</td>
#                     <td>0.262%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>0.5</td>
#                     <td>119</td>
#                     <td>0.26%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>1.1</td>
#                     <td>116</td>
#                     <td>0.254%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>3.8</td>
#                     <td>114</td>
#                     <td>0.249%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>"Missing"</td>
#                     <td>0</td>
#                     <td>0.0%</td>
#                 </tr>
#
#             </table>
#         </div>
#
#
#
#         <div class="panel_profiler">
#
#
#             <h3>Quantile statistics</h3>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>Minimum</td>
#                     <td>0.0</td>
#                 </tr>
#                 <tr>
#                     <td>5-th percentile</td>
#                     <td></td>
#                 </tr>
#                 <tr>
#                     <td>Q1</td>
#                     <td></td>
#                 </tr>
#                 <tr>
#                     <td>Median</td>
#                     <td></td>
#                 </tr>
#                 <tr>
#                     <td>Q3</td>
#                     <td></td>
#                 </tr>
#                 <tr>
#                     <td>95-th percentile</td>
#                     <td></td>
#                 </tr>
#                 <tr>
#                     <td>Maximum</td>
#                     <td>60000000.0</td>
#                 </tr>
#                 <tr>
#                     <td>Range</td>
#                     <td>60000000.0</td>
#                 </tr>
#                 <tr>
#                     <td>Interquartile range</td>
#                     <td>0.0</td>
#                 </tr>
#                 </tbody>
#             </table>
#         </div>
#         <div class="panel_profiler">
#             <h3>Descriptive statistics</h3>
#             <table>
#                 <tbody>
#                 <tr>

# %%
op.profiler.run(df, "year", infer=True)
# Out:
# Including 'nan' as Null in processing 'name'
# Including 'nan' as Null in processing 'nametype'
# Including 'nan' as Null in processing 'recclass'
# Including 'nan' as Null in processing 'fall'
# Including 'nan' as Null in processing 'year'
# Including 'nan' as Null in processing 'GeoLocation'
# <div class="title_profiler">
#     <h1>Overview</h1>
# </div>
# <div class="main">
#     <div class="panel_profiler">
#         <h2>Dataset info</h2>
#         <table>
#             <tbody>
#             <tr>
#                 <td>Number of columns</td>
#                 <td>10</td>
#
#             </tr>
#             <tr>
#                 <td>Number of rows</td>
#                 <td>45716</td>
#
#             </tr>
#             <tr>
#                 <td>Total Missing (%)</td>
#                 <td>0.49%</td>
#
#             </tr>
#             <tr>
#                 <td>Total size in memory</td>
#                 <td>-1 Bytes</td>
#
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="panel_profiler">
#         <h2>Column types</h2>
#         <table>
#             <tbody>
#             <tr>
#                 <td>String</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Numeric</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Date</td>
#                 <td>1</td>
#
#             </tr>
#             <tr>
#                 <td>Bool</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Array</td>
#                 <td>0</td>
#
#             </tr>
#             <tr>
#                 <td>Not available</td>
#                 <td>0</td>
#
#             </tr>
#             </tbody>
#         </table>
#     </div>
# </div><link rel="stylesheet" type="text/css" href="optimus/styles/styles.css">
#
#
# <div class="main">
#     <div class="info">
#
#
#
#         <div class="panel_profiler">
#             <div>
#                 <h2>year</h2>
#                 <span>date</span>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>Unique</td>
#                     <td> 265</td>
#                 </tr>
#                 <tr>
#                     <td>Unique (%)</td>
#                     <td> 0.58</td>
#                 </tr>
#                 <tr>
#                     <td>Missing</td>
#                     <td>0.0</td>
#                 </tr>
#                 <tr>
#                     <td>Missing (%)</td>
#                     <td>0</td>
#                 </tr>
#                 </tbody>
#             </table>
#             <div>
#                 <h3>
#                     Datatypes
#                 </h3>
#             </div>
#             <table>
#                 <tbody>
#                 <tr>
#                     <td>
#                         String
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Integer
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Float
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Bool
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Date
#                     </td>
#                     <td>
#                         45428
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Missing
#                     </td>
#                     <td>
#                         0
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         Null
#                     </td>
#                     <td>
#                         288
#                     </td>
#
#                 </tr>
#                 </tbody>
#             </table>
#
#
#         </div>
#         <div class="panel_profiler">
#             <h3>Frequency</h3>
#             <table>
#
#                 <tr>
#                     <th>Value</th>
#                     <th>Count</th>
#                     <th>Frecuency (%)</th>
#                 </tr>
#
#                 <tr>
#                     <td>01/01/2003 12:00:00 AM</td>
#                     <td>3323</td>
#                     <td>7.269%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/1979 12:00:00 AM</td>
#                     <td>3046</td>
#                     <td>6.663%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/1998 12:00:00 AM</td>
#                     <td>2697</td>
#                     <td>5.899%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/2006 12:00:00 AM</td>
#                     <td>2456</td>
#                     <td>5.372%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/1988 12:00:00 AM</td>
#                     <td>2296</td>
#                     <td>5.022%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/2002 12:00:00 AM</td>
#                     <td>2078</td>
#                     <td>4.545%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/2004 12:00:00 AM</td>
#                     <td>1940</td>
#                     <td>4.244%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/2000 12:00:00 AM</td>
#                     <td>1792</td>
#                     <td>3.92%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/1997 12:00:00 AM</td>
#                     <td>1696</td>
#                     <td>3.71%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>01/01/1999 12:00:00 AM</td>
#                     <td>1691</td>
#                     <td>3.699%</td>
#                 </tr>
#
#
#                 <tr>
#                     <td>"Missing"</td>
#                     <td>0</td>
#                     <td>0.0%</td>
#                 </tr>
#
#             </table>
#         </div>
#
#
#
#     </div>
#     <table>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#         <tr>
#             <td>
#                 <div>
#                     <img src="data:image/jpeg;base64,...">
#                 </div>
#
#             </td>
#
#         </tr>
#
#
#     </table>
# </div>
#
#
#
#
# <div class="info_items">Viewing 10 of 45716 rows / 10 columns</div>
# <div class="info_items">32 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th
